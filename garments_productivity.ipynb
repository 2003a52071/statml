# %% [markdown]
# <a href="https://colab.research.google.com/github/2003a52071/statml/blob/main/garments_productivity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('/garments_worker_productivity (2).csv')

# %%
data.head()
# Out:
#        date   quarter  ... no_of_workers actual_productivity
# 0  1/1/2015  Quarter1  ...          59.0            0.940725
# 1  1/1/2015  Quarter1  ...           8.0            0.886500
# 2  1/1/2015  Quarter1  ...          30.5            0.800570
# 3  1/1/2015  Quarter1  ...          30.5            0.800570
# 4  1/1/2015  Quarter1  ...          56.0            0.800382
#
# [5 rows x 15 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
y=data['actual_productivity']
x=data['date']
from matplotlib import pyplot as pt
pt.plot(x,y)

# %%
x=data['quarter']
pt.plot(x,y)

# %%
x=data['department']
pt.plot(x,y)

# %%
x=data['day']
pt.plot(x,y)

# %%
x=data['team']
pt.plot(x,y)

# %%
x=data['targeted_productivity']
pt.plot(x,y)

# %%
x=data['smv']
pt.plot(x,y)

# %%
x=data['wip']
pt.plot(x,y)

# %%
x=data['over_time']
pt.plot(x,y)

# %%
x=data['incentive']
pt.plot(x,y)

# %%
x=data['idle_time']
pt.plot(x,y)

# %%
x=data['idle_men']
pt.plot(x,y)

# %%
x=data['no_of_style_change']
pt.plot(x,y)

# %%
x=data['no_of_workers']
pt.plot(x,y)
